# %% [markdown]
# <div style="width:image width px; font-size:75%; text-align:right;">
#     <img src="img/joshua-woroniecki--desert.jpg" width="width" height="height" style="padding-bottom:0.2em;" />
#     <figcaption>Foto von Joshua Woroniecki auf Unsplash</figcaption>
# </div>

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(
    "NFA_2022_Country_Results.csv",
    header=21,
    sep=";",
    #skiprows=21,
    nrows=184,
    #nrows=2
)
data
data.dtypes
# Out:
# Country                                      object
# Data Quality                                 object
# SDGi                                         object
# Life Expectancy                             float64
# HDI                                          object
# Per Capita GDP                               object
# Region                                       object
# Income Group                                 object
# Population (millions)                        object
# Cropland Footprint                           object
# Grazing Footprint                            object
# Forest Product Footprint                     object
# Fish Footprint                               object
# Built up land                                object
# Carbon Footprint                             object
# Total Ecological Footprint (Production)      object
# Cropland Footprint.1                         object
# Grazing Footprint.1                          object
# Forest Product Footprint.1                   object
# Fish Footprint.1                             object
# Built up land.1                              object
# Carbon Footprint.1                           object
# Total Ecological Footprint (Consumption)     object
# Cropland                                     object
# Grazing land                                 object
# Forest land                                  object
# Fishing ground                               object
# Built up land.2                              object
# Total biocapacity                            object
# Ecological (Deficit) or Reserve              object
# Number of Earths required                    object
# Number of Countries required                 object
# actual \nCountry Overshoot Day \n2018        object
# Unnamed: 33                                 float64
# Unnamed: 34                                 float64
# Unnamed: 35                                 float64
# dtype: object

# %%
sns.pairplot(data)
