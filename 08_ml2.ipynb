# %% [markdown]
# <div style="width:image width px; font-size:75%; text-align:right;">
#     <img src="img/pexels-brandon-montrone-1179229.jpg" width="width" height="height" style="padding-bottom:0.2em;" />
#     <figcaption>Photo by Kaique Rocha on Pexels</figcaption>
# </div>

# %% [markdown]
# # Machine Learning 2
#
# **Applied Programming - Summer term 2023 - FOM Hochschule für Oekonomie und Management - Cologne**
#
# **Lecture 08 - May 19, 2023**

# %% [markdown]
# *Dennis Gluesenkamp*

# %% [markdown]
# ## Table of contents
# * [Dataset recap](#datarecap)
# * [Regression](#regression)
#     * [Linear regression](#regression_linear)
#     * [Lasso](#regression_lasso)
#     * [Random forest regressor](#regression_rf)
# * [Clustering](#clustering)
#     * [kMeans](#clustering_kmeans)
#     * [Alternative](#clustering_alternative)

# %% [markdown]
# ## Dataset recap<a class="anchor" id="datarecap"></a>

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.datasets import make_regression
from sklearn.datasets import load_breast_cancer
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %matplotlib inline

np.random.seed(42)

# %%
# Artificial classification problem:
X_c, y_c = make_classification(n_samples            = 1000,
                               n_features           = 10,
                               n_redundant          = 2,
                               n_informative        = 5,
                               n_classes            = 3,
                               n_clusters_per_class = 3,
                               flip_y               = 0.05,
                               shift                = None,
                               random_state         = 42)

# Artificial regression problem:
X_r, y_r = make_regression(n_samples     = 1000,
                           n_features    = 10,
                           n_informative = 5,
                           noise         = 0.05,
                           random_state  = 42)

# Scikit-learn toy dataset for classification:
X_b, y_b = load_breast_cancer(return_X_y = True)

# Scikit-learn toy dataset for regression:
X_d, y_d = load_diabetes(return_X_y = True)

# Kaggle dataset for regression:
# Medical Cost Personal Datasets - Insurance Forecast by using Linear Regression
# https://www.kaggle.com/mirichoi0218/insurance
df_i = pd.read_csv('dat/insurance.csv')

# Preprocessing
df_i_enc = pd.get_dummies(df_i, drop_first = True)

X_c_train, X_c_test, y_c_train, y_c_test = train_test_split(X_c, y_c,
                                                            test_size = 0.25,
                                                            random_state = 42)

X_r_train, X_r_test, y_r_train, y_r_test = train_test_split(X_r, y_r,
                                                            test_size = 0.25,
                                                            random_state = 42)

X_b_train, X_b_test, y_b_train, y_b_test = train_test_split(X_b, y_b,
                                                            test_size = 0.3,
                                                            random_state = 42)

X_d_train, X_d_test, y_d_train, y_d_test = train_test_split(X_d, y_d,
                                                            test_size = 0.3,
                                                            random_state = 42)

df_i_train, df_i_test = train_test_split(df_i_enc,
                                         test_size = 0.05,
                                         random_state = 42)

st_scaler = StandardScaler()
df_i_train_scaled = pd.DataFrame(st_scaler.fit_transform(df_i_train),
                                 columns = df_i_train.columns)
df_i_test_scaled  = pd.DataFrame(st_scaler.transform(df_i_test),
                                 columns = df_i_test.columns)

# %% [markdown]
# ## Regression<a class="anchor" id="regression"></a>
# In this second part we deal with regression. This is about the prediction of continuous values in contrast to classification with discrete groups. It follows directly that the target must be a numerical expression. An example of a regression problem is the prediction of prices.

# %% [markdown]
# ### Linear regression<a class="anchor" id="regression_linear"></a>
# The classic and simplest regression approach is linear regression. This is the representation of the target variable as a linear combination of the independent variables according to the following mathematical form.
# \begin{equation*}
# y\left(c,x\right) = c_0 + c_1 x_1 + \dots + c_n x_n
# \end{equation*}
# Here, $c = \left(c_0, c_1, \dots, c_n\right)$ is coefficient vector. The model adjusts the coefficients to minimize the sum of squares of real and approximated targets, which corresponds to the mathematical minimization problem
# \begin{equation*}
# \min_{c} \| Xc - Y \|^2.
# \end{equation*}

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

# Artificial regression problem
reg.fit(X_r_train, y_r_train)
# Out:
# LinearRegression()

# %%
# Calculate the coefficient of determination for test dataset
reg.score(X_r_test, y_r_test)
# Out:
# 0.99999950690563

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [ 5.82890289e+01 -1.99961207e-03  6.03616892e-04  3.21259368e+01
#   7.17867466e+00  1.61745631e-03  1.03011650e+01 -8.22508554e-04
#  -2.57251364e-03  9.42859646e+00]
# -0.0015324967650616195

# %%
# Index of feature
i = 0
plt.figure(figsize = (15,8))
plt.scatter(X_r_test[:, i], y_r_test,
            s = 50, marker = '^', color = 'blue', label = 'test', alpha = 0.6)
plt.scatter(X_r_test[:, i], reg.predict(X_r_test),
            s = 70, marker = 'v', color = 'orange', label = 'pred', alpha = 0.5)
plt.xlabel('Objects, X, feature ' + str(i))
plt.ylabel("Target, y")
plt.title("Linear regression")
plt.legend()
plt.draw()

# %%
# Diabetes dataset
reg.fit(X_d_train, y_d_train)
reg.score(X_d_test, y_d_test)
# Out:
# 0.4772897164322617

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  29.25401303 -261.7064691   546.29972304  388.39834056 -901.95966819
#   506.76324136  121.15435079  288.03526689  659.26895081   41.37670105]
# 151.00821291456543

# %%
# Index of variable
i = 2
plt.figure(figsize = (15,8))
plt.scatter(X_d_test[:, i], y_d_test,
            s = 50, marker = '^', color = 'blue', label = 'test', alpha = 0.6)
plt.scatter(X_d_test[:, i], reg.predict(X_d_test),
            s = 70, marker = 'v', color = 'orange', label = 'pred', alpha = 0.5)
plt.xlabel('Objects, X, feature ' + str(i))
plt.ylabel('Target, y')
plt.title('Linear regression')
plt.legend()
plt.draw()

# %% [markdown]
# ### Random forest regressor<a class="anchor" id="regression_rf"></a>
# We have already learned about Random Forests as a classification algorithm. However, they can also be used for regression problems.

# %%
from sklearn.ensemble import RandomForestRegressor

rf     = RandomForestRegressor(random_state = 42)
params = {'n_estimators': [50, 100, 200],
          #'criterion':    ['squared_error', 'friedman_mse', 'poisson'],
          'max_depth':    [2, 4, 6, 8]}
k      = 3

reg = GridSearchCV(rf, params, cv = k)
reg.fit(X_d_train, y_d_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson'],
#                          'max_depth': [2, 4, 6, 8],
#                          'n_estimators': [50, 100, 200]})

# %%
reg.score(X_d_test, y_d_test)
# Out:
# 0.4957329330350224

# %%
pd.DataFrame(reg.cv_results_).sort_values(by = ['rank_test_score'])
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time
# 17       0.430699      0.015787         0.018884        0.001280  \
# 5        0.450279      0.016831         0.023532        0.005132
# 20       0.488873      0.018066         0.019764        0.001894
# 8        0.494724      0.005261         0.024111        0.003432
# 4        0.216604      0.006236         0.013962        0.005996
# 16       0.213416      0.004556         0.013500        0.007487
# 2        0.403296      0.005108         0.024272        0.006098
# 14       0.396270      0.003153         0.021153        0.004682
# 1        0.722674      0.267948         0.025712        0.020716
# 13       0.203471      0.004481         0.014172        0.004499
# 7        0.236984      0.001910         0.010884        0.000463
# 19       0.230394      0.006355         0.010964        0.002216
# 15       0.107056      0.004531         0.005203        0.000620
# 3        0.110724      0.001297         0.004621        0.000157
# 23       0.512242      0.016235         0.022359        0.002170
# 11       0.509681      0.004307         0.023482        0.001271
# 6        0.120754      0.004930         0.006746        0.001389
# 18       0.122085      0.005114         0.004864        0.000187
# 0        0.293690      0.085912         0.009109        0.000825
# 12       0.095665      0.000893         0.004674        0.000159
# 10       0.261490      0.014543         0.013796        0.002923
# 22       0.289094      0.008332         0.014039        0.001807
# 29       0.462387      0.012258         0.018793        0.001102
# 32       0.524366      0.003746         0.019365        0.001019
# 31       0.263873      0.006521         0.013837        0.004775
# 35       0.563031      0.023273         0.018821        0.000268
# 28       0.228414      0.006658         0.010108        0.000396
# 9        0.131894      0.012661         0.006233        0.001023
# 21       0.145528      0.003099         0.009115        0.004652
# 34       0.274115      0.006921         0.010960        0.000359
# 26       0.396114      0.011634         0.021993        0.004761
# 30       0.126490      0.003585         0.008390        0.003437
# 25       0.205345      0.016754         0.012638        0.002236
# 27       0.121601      0.013785         0.005262        0.000671
# 24       0.100902      0.000541         0.005190        0.000785
# 33       0.147775      0.016472         0.006101        0.001457
#
#    param_criterion param_max_depth param_n_estimators
# 17    friedman_mse               4                200  \
# 5    squared_error               4                200
# 20    friedman_mse               6                200
# 8    squared_error               6                200
# 4    squared_error               4                100
# 16    friedman_mse               4                100
# 2    squared_error               2                200
# 14    friedman_mse               2                200
# 1    squared_error               2                100
# 13    friedman_mse               2                100
# 7    squared_error               6                100
# 19    friedman_mse               6                100
# 15    friedman_mse               4                 50
# 3    squared_error               4                 50
# 23    friedman_mse               8                200
# 11   squared_error               8                200
# 6    squared_error               6                 50
# 18    friedman_mse               6                 50
# 0    squared_error               2                 50
# 12    friedman_mse               2                 50
# 10   squared_error               8                100
# 22    friedman_mse               8                100
# 29         poisson               4                200
# 32         poisson               6                200
# 31         poisson               6                100
# 35         poisson               8                200
# 28         poisson               4                100
# 9    squared_error               8                 50
# 21    friedman_mse               8                 50
# 34         poisson               8                100
# 26         poisson               2                200
# 30         poisson               6                 50
# 25         poisson               2                100
# 27         poisson               4                 50
# 24         poisson               2                 50
# 33         poisson               8                 50
#
#                                                params  split0_test_score
# 17  {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.351560  \
# 5   {'criterion': 'squared_error', 'max_depth': 4,...           0.351560
# 20  {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.346788
# 8   {'criterion': 'squared_error', 'max_depth': 6,...           0.346788
# 4   {'criterion': 'squared_error', 'max_depth': 4,...           0.350110
# 16  {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.350110
# 2   {'criterion': 'squared_error', 'max_depth': 2,...           0.360734
# 14  {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.360734
# 1   {'criterion': 'squared_error', 'max_depth': 2,...           0.361480
# 13  {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.361480
# 7   {'criterion': 'squared_error', 'max_depth': 6,...           0.345030
# 19  {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.345030
# 15  {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.331100
# 3   {'criterion': 'squared_error', 'max_depth': 4,...           0.331100
# 23  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.335227
# 11  {'criterion': 'squared_error', 'max_depth': 8,...           0.335227
# 6   {'criterion': 'squared_error', 'max_depth': 6,...           0.336080
# 18  {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.336080
# 0   {'criterion': 'squared_error', 'max_depth': 2,...           0.349325
# 12  {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.349325
# 10  {'criterion': 'squared_error', 'max_depth': 8,...           0.335873
# 22  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.335873
# 29  {'criterion': 'poisson', 'max_depth': 4, 'n_es...           0.346629
# 32  {'criterion': 'poisson', 'max_depth': 6, 'n_es...           0.340299
# 31  {'criterion': 'poisson', 'max_depth': 6, 'n_es...           0.335113
# 35  {'criterion': 'poisson', 'max_depth': 8, 'n_es...           0.336445
# 28  {'criterion': 'poisson', 'max_depth': 4, 'n_es...           0.340465
# 9   {'criterion': 'squared_error', 'max_depth': 8,...           0.316129
# 21  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.316129
# 34  {'criterion': 'poisson', 'max_depth': 8, 'n_es...           0.332605
# 26  {'criterion': 'poisson', 'max_depth': 2, 'n_es...           0.347941
# 30  {'criterion': 'poisson', 'max_depth': 6, 'n_es...           0.321315
# 25  {'criterion': 'poisson', 'max_depth': 2, 'n_es...           0.348497
# 27  {'criterion': 'poisson', 'max_depth': 4, 'n_es...           0.318345
# 24  {'criterion': 'poisson', 'max_depth': 2, 'n_es...           0.335445
# 33  {'criterion': 'poisson', 'max_depth': 8, 'n_es...           0.317749
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score
# 17           0.506901           0.391997         0.416819        0.065802  \
# 5            0.506901           0.391997         0.416819        0.065802
# 20           0.505441           0.386199         0.412809        0.067448
# 8            0.505441           0.386199         0.412809        0.067448
# 4            0.495686           0.382163         0.409320        0.062457
# 16           0.495686           0.382163         0.409320        0.062457
# 2            0.473543           0.389925         0.408067        0.047807
# 14           0.473543           0.389925         0.408067        0.047807
# 1            0.467587           0.391503         0.406857        0.044658
# 13           0.467587           0.391503         0.406857        0.044658
# 7            0.496505           0.375551         0.405695        0.065410
# 19           0.496505           0.375551         0.405695        0.065410
# 15           0.497303           0.387401         0.405268        0.069018
# 3            0.497303           0.387401         0.405268        0.069018
# 23           0.499038           0.381324         0.405196        0.068973
# 11           0.499038           0.381324         0.405196        0.068973
# 6            0.502518           0.373445         0.404014        0.071304
# 18           0.502518           0.373445         0.404014        0.071304
# 0            0.465133           0.394116         0.402858        0.047681
# 12           0.465133           0.394116         0.402858        0.047681
# 10           0.497830           0.373000         0.402234        0.069275
# 22           0.497830           0.373000         0.402234        0.069275
# 29           0.496227           0.362217         0.401691        0.067149
# 32           0.502276           0.357697         0.400091        0.072604
# 31           0.495002           0.358114         0.396077        0.070579
# 35           0.494441           0.352948         0.394611        0.070911
# 28           0.482153           0.360235         0.394284        0.062654
# 9            0.500176           0.365921         0.394076        0.077729
# 21           0.500176           0.365921         0.394076        0.077729
# 34           0.482645           0.362987         0.392746        0.064767
# 26           0.464273           0.355852         0.389355        0.053073
# 30           0.483597           0.357144         0.387352        0.069609
# 25           0.459784           0.353477         0.387253        0.051328
# 27           0.475912           0.367492         0.387250        0.065826
# 24           0.454376           0.365137         0.384986        0.050541
# 33           0.473885           0.354250         0.381961        0.066686
#
#     rank_test_score
# 17                1
# 5                 1
# 20                3
# 8                 3
# 4                 5
# 16                5
# 2                 7
# 14                7
# 1                 9
# 13                9
# 7                11
# 19               11
# 15               13
# 3                13
# 23               15
# 11               15
# 6                17
# 18               17
# 0                19
# 12               19
# 10               21
# 22               21
# 29               23
# 32               24
# 31               25
# 35               26
# 28               27
# 9                28
# 21               28
# 34               30
# 26               31
# 30               32
# 25               33
# 27               34
# 24               35
# 33               36

# %%
# Index of variable
i = 2
plt.figure(figsize = (15,8))
plt.scatter(X_d_test[:, i], y_d_test,
            s = 50, marker = '^', color = 'blue', label = 'test', alpha = 0.6)
plt.scatter(X_d_test[:, i], reg.predict(X_d_test),
            s = 70, marker = 'v', color = 'orange', label = 'pred', alpha = 0.5)
plt.xlabel('Objects, X, feature ' + str(i))
plt.ylabel('Target, y')
plt.title('Random forest regression')
plt.legend()
plt.draw()

# %% [markdown]
# #### Exercises
# Train one random forest regressor model and another one of your choice for the insurance dataset.

# %%
rf_ins     = RandomForestRegressor(random_state = 42)
params = {'n_estimators': [25, 50, 100, 200],
          'criterion':    ['friedman_mse'],
          'max_depth':    [2, 4, 6, 8, 10]}
k      = 3

reg_ins = GridSearchCV(rf_ins, params, cv = k)
reg_ins.fit(df_i_train_scaled.drop('charges', axis = 1), df_i_train_scaled['charges'])
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'criterion': ['friedman_mse'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'n_estimators': [25, 50, 100, 200]})

# %%
reg_ins.score(df_i_test_scaled.drop('charges', axis = 1), df_i_test_scaled['charges'])
# Out:
# 0.8716382711288363

# %%
pd.DataFrame(reg_ins.cv_results_).sort_values(by = ['rank_test_score'])
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time
# 5        0.141651      0.018352         0.009554        0.001131  \
# 4        0.081880      0.019221         0.012758        0.010007
# 7        0.526222      0.045506         0.029664        0.005046
# 6        0.328678      0.102329         0.018709        0.006791
# 11       0.564885      0.018473         0.026520        0.001054
# 9        0.206955      0.097738         0.011828        0.004745
# 10       0.363045      0.115537         0.019587        0.005184
# 8        0.074368      0.001704         0.005091        0.000401
# 13       0.162210      0.006554         0.012374        0.003087
# 15       0.694838      0.053522         0.029922        0.000289
# 14       0.320536      0.010718         0.020477        0.004570
# 12       0.087188      0.005858         0.006986        0.000577
# 17       0.178163      0.006080         0.012846        0.003790
# 19       0.806415      0.106225         0.035906        0.004304
# 18       0.366168      0.002378         0.017999        0.000695
# 16       0.091912      0.002142         0.007116        0.000199
# 3        0.445683      0.041264         0.024045        0.000298
# 2        0.238940      0.040673         0.015098        0.002461
# 1        0.125566      0.026891         0.007241        0.000292
# 0        0.144160      0.013505         0.009923        0.007370
#
#    param_criterion param_max_depth param_n_estimators
# 5     friedman_mse               4                 50  \
# 4     friedman_mse               4                 25
# 7     friedman_mse               4                200
# 6     friedman_mse               4                100
# 11    friedman_mse               6                200
# 9     friedman_mse               6                 50
# 10    friedman_mse               6                100
# 8     friedman_mse               6                 25
# 13    friedman_mse               8                 50
# 15    friedman_mse               8                200
# 14    friedman_mse               8                100
# 12    friedman_mse               8                 25
# 17    friedman_mse              10                 50
# 19    friedman_mse              10                200
# 18    friedman_mse              10                100
# 16    friedman_mse              10                 25
# 3     friedman_mse               2                200
# 2     friedman_mse               2                100
# 1     friedman_mse               2                 50
# 0     friedman_mse               2                 25
#
#                                                params  split0_test_score
# 5   {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.853696  \
# 4   {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.852090
# 7   {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.852221
# 6   {'criterion': 'friedman_mse', 'max_depth': 4, ...           0.852511
# 11  {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.855033
# 9   {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.854424
# 10  {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.854849
# 8   {'criterion': 'friedman_mse', 'max_depth': 6, ...           0.852185
# 13  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.849495
# 15  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.850272
# 14  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.850202
# 12  {'criterion': 'friedman_mse', 'max_depth': 8, ...           0.845114
# 17  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.844622
# 19  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.845855
# 18  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.845133
# 16  {'criterion': 'friedman_mse', 'max_depth': 10,...           0.839034
# 3   {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.832410
# 2   {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.832515
# 1   {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.832048
# 0   {'criterion': 'friedman_mse', 'max_depth': 2, ...           0.830764
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score
# 5            0.880656           0.826160         0.853504        0.022248  \
# 4            0.881001           0.826662         0.853251        0.022199
# 7            0.879340           0.826887         0.852816        0.021418
# 6            0.879499           0.826434         0.852815        0.021665
# 11           0.872332           0.823379         0.850248        0.020269
# 9            0.872909           0.822125         0.849819        0.020987
# 10           0.871241           0.821816         0.849302        0.020555
# 8            0.871427           0.821291         0.848301        0.020651
# 13           0.860272           0.813634         0.841134        0.019936
# 15           0.858053           0.812893         0.840406        0.019712
# 14           0.858785           0.811100         0.840029        0.020754
# 12           0.856495           0.809294         0.836968        0.020112
# 17           0.852857           0.807578         0.835019        0.019693
# 19           0.849805           0.808092         0.834584        0.018802
# 18           0.850403           0.807552         0.834362        0.019080
# 16           0.850734           0.800685         0.830151        0.021376
# 3            0.845597           0.806378         0.828128        0.016295
# 2            0.845379           0.806333         0.828076        0.016247
# 1            0.844977           0.806568         0.827864        0.015957
# 0            0.845442           0.806520         0.827575        0.016049
#
#     rank_test_score
# 5                 1
# 4                 2
# 7                 3
# 6                 4
# 11                5
# 9                 6
# 10                7
# 8                 8
# 13                9
# 15               10
# 14               11
# 12               12
# 17               13
# 19               14
# 18               15
# 16               16
# 3                17
# 2                18
# 1                19
# 0                20

# %% [markdown]
# ## Clustering<a class="anchor" id="clustering"></a>
# We will conclude the two lectures on machine learning with a method of unsupervised learning, namely clustering. This refers to the discovery of structures in the data set that exhibit similarities between objects. The objects found in this way are assigned to groups called clusters. Clustering thus aims at new findings that were not previously available. The algorithm formed in this way can also be applied to previously unknown data in order to make an appropriate assignment.

# %% [markdown]
# ### kMeans<a class="anchor" id="clustering_kmeans"></a>
# Apply the k-means algorithm to arbitrary high-dimensional data. The method first chooses $k$ centers as the starting points. Then, an assignment of the objects in the data set to these centers is performed. This is done based on the distance of the objects to the centers. Subsequently, the cluster centers are recalculated based on the points. The assignment and recalculation is then repeated until there is no change.

# %%
plt.figure(figsize = (15, 8))
plt.scatter(X_c[:, 0], X_c[:, 4], s = 25, c = y_c, alpha = 0.6)
plt.xlabel('X_0')
plt.ylabel('X_4')
plt.title('Artificial classification problem')
plt.draw()

# %%
from sklearn.cluster import KMeans
y_c_pred = KMeans(n_clusters = 3, n_init = 100, max_iter = 1000, random_state = 42).fit_predict(X_c)

# %%
df_c = pd.concat([pd.DataFrame(X_c), pd.DataFrame(y_c), pd.DataFrame(y_c_pred)], axis = 1)
df_c.columns = ['X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'y', 'y_pred']
df_c.sample(5)
# Out:
#            X0        X1        X2        X3        X4        X5        X6
# 521  0.838312 -0.683373 -0.539634  0.061437 -1.685973 -1.538815 -1.020704  \
# 737  3.814769  1.943726 -0.743245  1.971120  0.765928  0.682011 -0.948186
# 740 -2.091814  0.126654  0.558342  0.290806 -1.465690 -0.728211  1.687304
# 660 -1.259101 -0.095008  0.528524  0.340215 -0.780365 -0.448834  1.382272
# 411 -0.589176 -0.390692  0.305719  1.329758 -2.955167 -0.796572 -0.656377
#
#            X7        X8        X9  y  y_pred
# 521 -0.704525 -1.272034 -2.543436  2       0
# 737 -2.263904  0.537334  0.470680  1       1
# 740  0.373620 -0.715997  0.950814  0       2
# 660 -0.430402  0.408721  0.697985  1       2
# 411 -0.029314 -0.963237  1.010841  1       2

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (15, 8))
ax[0].scatter(df_c[df_c['y'] == 0]['X0'], df_c[df_c['y'] == 0]['X4'],
              s = 25, c = df_c[df_c['y'] == 0]['y_pred'], alpha = 0.7)
ax[0].set_title('Class 0')
ax[1].scatter(df_c[df_c['y'] == 1]['X0'], df_c[df_c['y'] == 1]['X4'],
              s = 25, c = df_c[df_c['y'] == 1]['y_pred'], alpha = 0.7)
ax[1].set_title('Class 1')
ax[2].scatter(df_c[df_c['y'] == 2]['X0'], df_c[df_c['y'] == 2]['X4'],
              s = 25, c = df_c[df_c['y'] == 2]['y_pred'], alpha = 0.7)
ax[2].set_title('Class 2')
plt.draw()

# %% [markdown]
# ### Alternative<a class="anchor" id="clustering_alternative"></a>

# %%
from sklearn.cluster import AgglomerativeClustering

y_c_pred = AgglomerativeClustering(n_clusters = 3).fit_predict(X_c)

df_c = pd.concat([pd.DataFrame(X_c), pd.DataFrame(y_c), pd.DataFrame(y_c_pred)], axis = 1)
df_c.columns = ['X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'y', 'y_pred']

fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (15, 8))
ax[0].scatter(df_c[df_c['y'] == 0]['X0'], df_c[df_c['y'] == 0]['X4'],
              s = 25, c = df_c[df_c['y'] == 0]['y_pred'], alpha = 0.7)
ax[0].set_title('Class 0')
ax[1].scatter(df_c[df_c['y'] == 1]['X0'], df_c[df_c['y'] == 1]['X4'],
              s = 25, c = df_c[df_c['y'] == 1]['y_pred'], alpha = 0.7)
ax[1].set_title('Class 1')
ax[2].scatter(df_c[df_c['y'] == 2]['X0'], df_c[df_c['y'] == 2]['X4'],
              s = 25, c = df_c[df_c['y'] == 2]['y_pred'], alpha = 0.7)
ax[2].set_title('Class 2')
plt.draw()

# %% [markdown]
# <hr>
